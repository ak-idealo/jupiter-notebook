# %% [markdown]
# # querying the data lake in a jupyter notebook

# %% [markdown]
# ## prerequisites

# %% [markdown]
# make sure you have `pip install presto-python-client` and `pandas` and `matplotlib` installed.
# you may do that via `pip install <name from above>`

# %%
import prestodb

# %%
conn=prestodb.dbapi.connect(
    host='presto.apps.eu.idealo.com',
    port=443, user='aishwarya.kumar',
    catalog='hive',
    http_scheme='https',
    schema='default',)

# %%
conn

# %% [markdown]
# ## creating a cursor object instance

# %%
# create the cursor
cur = conn.cursor()
# cursor objects functions and attributes
[thing for thing in dir(cur) if '_' not in thing]
# Out:
# ['arraysize',
#  'cancel',
#  'close',
#  'connection',
#  'description',
#  'execute',
#  'executemany',
#  'fetchall',
#  'fetchmany',
#  'fetchone',
#  'genall',
#  'rowcount',
#  'setinputsizes',
#  'setoutputsize',
#  'stats']

# %% [markdown]
# ## exploring the schemas and tables

# %%
#schema either in double quotes or without quotes!
cur.execute('''
SHOW TABLES from "dl_inventory_intelligence_prod"
''')
records = cur.fetchall()
list(records)
# Out:
# [['fake_shop'],
#  ['feed_quality_layer'],
#  ['kpi_product'],
#  ['kpi_product_offers'],
#  ['kpi_shop'],
#  ['merchant_dk'],
#  ['pareto_clusters'],
#  ['priceapi_processed'],
#  ['tidy_category_tree']]

# %% [markdown]
# ## creating a cursor and querying

# %% [markdown]
# query can be highlighted in markdown code blocks (between triple backtics \`\`\`) for better readability
# ```sql
# SELECT *
# FROM "dl_dwh_prod"."so_facts"
# WHERE random(1000) = 1
# limit 1000
# ```

# %% [markdown]
# ## storing the results in a dataframe

# %%
import pandas as pd

# %%
cur.execute('''
WITH tidy_tree AS (
 SELECT distinct
  category_id,root_category_name,sub_category_name_de,category_name_de
  from dl_inventory_intelligence_prod.tidy_category_tree
  )
  
SELECT
date_format(date(date),'%Y-%m') AS  month_year,
root_category_name,
sub_category_name_de,
sum(pageimpression_oop) as pageimpression_oop,
sum(leadouts_oop)+ sum(checkouts_oop) as LOCO_OOP
FROM "dl_inventory_intelligence_prod"."kpi_product" a 
join tidy_tree t on a.category_id=t.category_id
where site like '%idealo.de%' and date < '2021-09-01'
group by 1,2,3
order by 1,2,3
''') # this was a multiline string.
records = cur.fetchall()
print("Total rows are: ", len(records))
# Out:
# Total rows are:  2503

# %%
#getting colnames from description, which is a list of columns with header and their entries
colnames = [col[0] for col in cur.description]
colnames[0:5]
#creating dataframe
df = pd.DataFrame(records, columns=colnames)
df['date'] = pd.to_datetime(df['month_year'])

# %%
df.head(5)
# Out:
#   month_year root_category_name       sub_category_name_de  \
# 0    2019-07    Auto & Motorrad   Anhänger & Trägersysteme
# 1    2019-07    Auto & Motorrad                Auto Tuning
# 2    2019-07    Auto & Motorrad  Auto-Werkstattausstattung
# 3    2019-07    Auto & Motorrad                 Autopflege
# 4    2019-07    Auto & Motorrad                   Autoteil
#
#    pageimpression_oop  LOCO_OOP       date
# 0            302769.0  102122.0 2019-07-01
# 1                 0.0       0.0 2019-07-01
# 2             39920.0   11170.0 2019-07-01
# 3             61489.0   12077.0 2019-07-01
# 4            138994.0   45818.0 2019-07-01

# %%
df.hist(column='pageimpression_oop', range=[1,10000],bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'pageimpression_oop'}>]],
#       dtype=object)

# %%
subset=df[(df.sub_category_name_de=="Garten")]
subset.plot( 'month_year' , 'pageimpression_oop' )
# Out:
# <AxesSubplot:xlabel='month_year'>

# %%
sub_cat=df.groupby(['month_year','year','sub_category_name_de'],as_index=False).pageimpression_oop.sum()

root_cat=df.groupby(['month_year','year','root_category_name'],as_index=False).pageimpression_oop.sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-6f3edea28f81> in <module>
# ----> 1 sub_cat=df.groupby(['month_year','year','sub_category_name_de'],as_index=False).pageimpression_oop.sum()
#       2
#       3 root_cat=df.groupby(['month_year','year','root_category_name'],as_index=False).pageimpression_oop.sum()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'year'

# %%
subset
subset_1=subset[['date','pageimpression_oop']].set_index("date").to_period("M")
subset_1
# Out:
#          pageimpression_oop
# date
# 2019-07           4256061.0
# 2019-08           3278541.0
# 2019-09           2457913.0
# 2019-10           2137127.0
# 2019-11           2105234.0
# 2019-12           1712171.0
# 2020-01           2046163.0
# 2020-02           2660371.0
# 2020-03           6160898.0
# 2020-04          15860204.0
# 2020-05          13579616.0
# 2020-06          10197406.0
# 2020-07           7743884.0
# 2020-08           7055242.0
# 2020-09           4199970.0
# 2020-10           3881750.0
# 2020-11           4556663.0
# 2020-12           3533866.0
# 2021-01           4285670.0
# 2021-02           5684250.0
# 2021-03           8619833.0
# 2021-04          10733550.0
# 2021-05          11082937.0
# 2021-06          10401072.0
# 2021-07           6904526.0
# 2021-08            831144.0

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot


def parser(x):
    return datetime.strptime(x, '%Y-%m')

#my_series = subset['pageimpression_oop'].squeeze()
#series = read_csv('shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#autocorrelation_plot(my_series)
#pyplot.show()

from statsmodels.graphics.tsaplots import plot_acf
#data["diff"].iloc[0] = 0
plot_acf(subset["pageimpression_oop"])
pyplot.show()

#lag=2
# Out:
# <ipython-input-15-5d6d131128b7>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

res = seasonal_decompose(subset_1, model = "additive",period = 12)

fig, (ax1,ax2,ax3) = pyplot.subplots(3,1, figsize=(15,8))
res.trend.plot(ax=ax1,ylabel = "trend")
res.resid.plot(ax=ax2,ylabel = "seasoanlity")
res.seasonal.plot(ax=ax3,ylabel = "residual")
pyplot.show()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_result=adfuller(subset['pageimpression_oop'])

# %%
def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(subset['pageimpression_oop'])
# Out:
# ADF Test Statistic : -2.8545018397357995
# p-value : 0.050900403692769144
# #Lags Used : 1
# Number of Observations : 24
# weak evidence against null hypothesis,indicating it is non-stationary

# %%
subset['PI First Difference'] = subset['pageimpression_oop'] - subset['pageimpression_oop'].shift(1)
subset['Seasonal First Difference']=subset['pageimpression_oop']-subset['pageimpression_oop'].shift(12)
subset['Seasonal First Difference Difference'] = subset['Seasonal First Difference'] - subset['Seasonal First Difference'].shift(1)
subset.head(20)
# Out:
# <ipython-input-134-235b3d2c6af2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['PI First Difference'] = subset['pageimpression_oop'] - subset['pageimpression_oop'].shift(1)
# <ipython-input-134-235b3d2c6af2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Seasonal First Difference']=subset['pageimpression_oop']-subset['pageimpression_oop'].shift(12)
# <ipython-input-134-235b3d2c6af2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Seasonal First Difference Difference'] = subset['Seasonal First Difference'] - subset['Seasonal First Difference'].shift(1)
#      month_year root_category_name sub_category_name_de  pageimpression_oop  \
# 55      2019-07      Haus & Garten               Garten           4256061.0
# 146     2019-08      Haus & Garten               Garten           3278541.0
# 239     2019-09      Haus & Garten               Garten           2457913.0
# 331     2019-10      Haus & Garten               Garten           2137127.0
# 426     2019-11      Haus & Garten               Garten           2105234.0
# 520     2019-12      Haus & Garten               Garten           1712171.0
# 616     2020-01      Haus & Garten               Garten           2046163.0
# 714     2020-02      Haus & Garten               Garten           2660371.0
# 812     2020-03      Haus & Garten               Garten           6160898.0
# 908     2020-04      Haus & Garten               Garten          15860204.0
# 1008    2020-05      Haus & Garten               Garten          13579616.0
# 1107    2020-06      Haus & Garten               Garten          10197406.0
# 1204    2020-07      Haus & Garten               Garten           7743884.0
# 1300    2020-08      Haus & Garten               Garten           7055242.0
# 1395    2020-09      Haus & Garten               Garten           4199970.0
# 1492    2020-10      Haus & Garten               Garten           3881750.0
# 1588    2020-11      Haus & Garten               Garten           4556663.0
# 1685    2020-12      Haus & Garten               Garten           3533866.0
# 1783    2021-01      Haus & Garten               Garten           4285670.0
# 1881    2021-02      Haus & Garten               Garten           5684250.0
#
#        LOCO_OOP       date  PI First Difference  Seasonal First Difference  \
# 55    1270976.0 2019-07-01                  NaN                        NaN
# 146    964047.0 2019-08-01            -977520.0                        NaN
# 239    699785.0 2019-09-01            -820628.0                        NaN
# 331    603896.0 2019-10-01            -320786.0                        NaN
# 426    538696.0 2019-11-01             -31893.0                        NaN
# 520    420692.0 2019-12-01            -393063.0                        NaN
# 616    539126.0 2020-01-01             333992.0                        NaN
# 714    715658.0 2020-02-01             614208.0                        NaN
# 812   1703236.0 2020-03-01            3500527.0                        NaN
# 908   4055637.0 2020-04-01            9699306.0                        NaN
# 1008  3443409.0 2020-05-01           -2280588.0                        NaN
# 1107  2795767.0 2020-06-01           -3382210.0                        NaN
# 1204  1879300.0 2020-07-01           -2453522.0                  3487823.0
# 1300  1664081.0 2020-08-01            -688642.0                  3776701.0
# 1395  1014342.0 2020-09-01           -2855272.0                  1742057.0
# 1492   833220.0 2020-10-01            -318220.0                  1744623.0
# 1588   886699.0 2020-11-01             674913.0                  2451429.0
# 1685   679496.0 2020-12-01           -1022797.0                  1821695.0
# 1783   823733.0 2021-01-01             751804.0                  2239507.0
# 1881  1198848.0 2021-02-01            1398580.0                  3023879.0
#
#       Seasonal First Difference Difference
# 55                                     NaN
# 146                                    NaN
# 239                                    NaN
# 331                                    NaN
# 426                                    NaN
# 520                                    NaN
# 616                                    NaN
# 714                                    NaN
# 812                                    NaN
# 908                                    NaN
# 1008                                   NaN
# 1107                                   NaN
# 1204                                   NaN
# 1300                              288878.0
# 1395                            -2034644.0
# 1492                                2566.0
# 1588                              706806.0
# 1685                             -629734.0
# 1783                              417812.0
# 1881                              784372.0

# %%
# Again testing if data is stationary
adfuller_test(subset['Seasonal First Difference'].dropna())
# Out:
# ADF Test Statistic : 0.6018670092994006
# p-value : 0.9876615574413838
# #Lags Used : 5
# Number of Observations : 8
# weak evidence against null hypothesis,indicating it is non-stationary

# %%
subset.plot( 'month_year' , 'Seasonal First Difference' )
# Out:
# <AxesSubplot:xlabel='month_year'>

# %%
subset_1.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
import warnings
import itertools
import numpy as np

p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter for SARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter for SARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(subset_1,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param,param_seasonal,results.aic))
        except: 
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:862.7541436761543
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:428.0582298599601
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:430.59923999664693
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:35.661897038338594
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:461.41359571839126
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:429.87902202401375
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:68.95595930507098
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:37.66189691303181
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:812.6942317435103
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:406.1463173810883
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:393.7584939298687
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:6.0
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:473.43000660415214
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:408.019933368902
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:69.1588802597362
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:8.0
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:785.4568514334846
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:390.49593447162584
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:399.16018410130033
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:4.0
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:420.2679657958657
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:392.2999507650067
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:35.55247950691776
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:6.0
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:751.7625922994948
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:358.5756425662057
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:363.7693394468664
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:6.0
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:423.07237142450515
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:360.5479162789425
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:37.88528866288642
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:8.0
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:817.9227539554889
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:422.9923840596764
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:425.9669883605209
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:37.459007569087454
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:422.9338302071865
# /Users/aishwarya.kumar/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:424.9011021087075
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:37.45899910965522
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:39.45900150834315
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:783.5204141278007
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:391.8341349898423
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:395.5745074692248
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:8.0
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:423.734060115364
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:393.333647559387
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:39.58303502994859
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:10.0
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:783.763049632714
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:389.323435959872
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:396.3864266951474
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:6.0
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:389.3057770484365
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:391.304779002627
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:6.0
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:8.0
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:753.6772522060621
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:359.7339895291172
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:365.513349118173
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:8.0
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:392.07644105152156
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:361.72629878960925
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:8.0
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:10.0

# %%
import statsmodels.api as sm

mod = sm.tsa.statespace.SARIMAX(subset_1,
                                order=(3,1,1),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0267      0.437      2.347      0.019       0.169       1.884
# ar.L2         -0.4099      1.296     -0.316      0.752      -2.950       2.130
# ar.L3         -0.1992      0.987     -0.202      0.840      -2.133       1.735
# ma.L1         -1.0406      0.080    -13.032      0.000      -1.197      -0.884
# sigma2      8.023e+12   2.59e-13    3.1e+25      0.000    8.02e+12    8.02e+12
# ==============================================================================

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-11-01'), end=pd.to_datetime('2022-06-01'),dynamic=False)
pred_ci = pred.conf_int()
ax = subset_1.plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(20,7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Demand')
pyplot.legend()
pyplot.show()
pred.predicted_mean
# Out:
# 2019-11    4.192798e+06
# 2019-12    4.539794e+06
# 2020-01    4.328101e+06
# 2020-02    4.931183e+06
# 2020-03    5.595439e+06
# 2020-04    8.848120e+06
# 2020-05    1.696419e+07
# 2020-06    1.008771e+07
# 2020-07    5.613876e+06
# 2020-08    4.848794e+06
# 2020-09    5.731328e+06
# 2020-10    3.632989e+06
# 2020-11    4.603600e+06
# 2020-12    5.997498e+06
# 2021-01    4.834271e+06
# 2021-02    5.913222e+06
# 2021-03    7.253975e+06
# 2021-04    9.489419e+06
# 2021-05    1.012724e+07
# 2021-06    8.996135e+06
# 2021-07    7.674831e+06
# 2021-08    4.326192e+06
# 2021-09   -1.982929e+05
# 2021-10    1.930442e+06
# 2021-11    5.747450e+06
# 2021-12    8.998813e+06
# 2022-01    1.034850e+07
# 2022-02    9.641398e+06
# 2022-03    7.714705e+06
# 2022-04    5.757631e+06
# 2022-05    4.678856e+06
# 2022-06    4.757153e+06
# Freq: M, Name: predicted_mean, dtype: float64

# %%
subset=df[(df.sub_category_name_de=="Caravaning")]
subset.plot( 'month_year' , 'pageimpression_oop' )
y=subset[['date','pageimpression_oop']].set_index("date").to_period("M")

# %%
# Split Train & Test Data
y_train=y[:len(y)-1]
y_test=y[len(y)-1:]

# %%
y_train.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# testing for stationarity of the data
from statsmodels.tsa.stattools import adfuller
from math import log
result = adfuller(y_train['pageimpression_oop'])
print('ADF Statistic for Caravaning: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value)) # data is not stationary
# Out:
# ADF Statistic for Caravaning: -0.802242
# p-value: 0.818463
# Critical Values:
# 	1%: -3.924
# 	5%: -3.068
# 	10%: -2.674

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
res = seasonal_decompose(y_train, model = "additive",period = 12)

fig, (ax1,ax2,ax3) = pyplot.subplots(3,1, figsize=(15,8))
res.trend.plot(ax=ax1,ylabel = "trend")
res.resid.plot(ax=ax2,ylabel = "seasoanlity")
res.seasonal.plot(ax=ax3,ylabel = "residual")
pyplot.show()

# %%
#plotting acf and pacf
from pandas import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
import statsmodels.api as sm


def parser(x):
    return datetime.strptime(x, '%Y-%m')

#my_series = subset['pageimpression_oop'].squeeze()
#series = read_csv('shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#autocorrelation_plot(my_series)
#pyplot.show()

from statsmodels.graphics.tsaplots import plot_acf
#data["diff"].iloc[0] = 0
plot_acf(y_train["pageimpression_oop"])
sm.graphics.tsa.plot_pacf(y_train["pageimpression_oop"].squeeze(), lags=11)
pyplot.show()

#lag=2
# Out:
# <ipython-input-24-4a79154bf5d8>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
import itertools
import warnings
warnings.filterwarnings("ignore")

def sarima_grid_search(y,seasonal_period):
    p = d = q = range(0, 3)
    pdq = list(itertools.product(p, d, q))
    seasonal_pdq = [(x[0], x[1], x[2],seasonal_period) for x in list(itertools.product(p, d, q))]
    
    mini = float('+inf')
    
    
    for param in pdq:
        for param_seasonal in seasonal_pdq:
            try:
                mod = sm.tsa.statespace.SARIMAX(y,
                                                order=param,
                                                seasonal_order=param_seasonal,
                                                enforce_stationarity=False,
                                                enforce_invertibility=False)

                results = mod.fit()
                
                if results.aic < mini:
                    mini = results.aic
                    param_mini = param
                    param_seasonal_mini = param_seasonal

                print('SARIMA{}x{} - AIC:{}'.format(param, param_seasonal, results.aic))
            except:
                continue
    print('The set of parameters with the minimum AIC is: SARIMA{}x{} - AIC:{}'.format(param_mini, param_seasonal_mini, mini))
    
sarima_grid_search(y_train,12)
# Out:
# SARIMA(0, 0, 0)x(0, 0, 0, 12) - AIC:605.648995652419
# SARIMA(0, 0, 0)x(0, 0, 1, 12) - AIC:280.4272189160376
# SARIMA(0, 0, 0)x(0, 0, 2, 12) - AIC:6.0
# SARIMA(0, 0, 0)x(0, 1, 0, 12) - AIC:294.6969351669959
# SARIMA(0, 0, 0)x(0, 1, 1, 12) - AIC:4.0
# SARIMA(0, 0, 0)x(0, 1, 2, 12) - AIC:6.0
# SARIMA(0, 0, 0)x(0, 2, 0, 12) - AIC:2.0
# SARIMA(0, 0, 0)x(1, 0, 0, 12) - AIC:300.20443328967366
# SARIMA(0, 0, 0)x(1, 0, 1, 12) - AIC:280.85790214616804
# SARIMA(0, 0, 0)x(1, 0, 2, 12) - AIC:8.0
# SARIMA(0, 0, 0)x(1, 1, 0, 12) - AIC:25.088936340168235
# SARIMA(0, 0, 0)x(1, 1, 1, 12) - AIC:6.0
# SARIMA(0, 0, 0)x(1, 1, 2, 12) - AIC:8.0
# SARIMA(0, 0, 0)x(2, 0, 0, 12) - AIC:28.594155496402585
# SARIMA(0, 0, 0)x(2, 0, 1, 12) - AIC:30.554939433206926
# SARIMA(0, 0, 0)x(2, 0, 2, 12) - AIC:10.0
# SARIMA(0, 0, 0)x(2, 1, 0, 12) - AIC:6.0
# SARIMA(0, 0, 0)x(2, 1, 1, 12) - AIC:8.0
# SARIMA(0, 0, 0)x(2, 1, 2, 12) - AIC:10.0
# SARIMA(0, 0, 1)x(0, 0, 0, 12) - AIC:567.8724658568789
# SARIMA(0, 0, 1)x(0, 0, 1, 12) - AIC:272.50404225850167
# SARIMA(0, 0, 1)x(0, 0, 2, 12) - AIC:8.0
# SARIMA(0, 0, 1)x(0, 1, 0, 12) - AIC:261.176725749566
# SARIMA(0, 0, 1)x(0, 1, 1, 12) - AIC:6.0
# SARIMA(0, 0, 1)x(0, 1, 2, 12) - AIC:8.0
# SARIMA(0, 0, 1)x(1, 0, 0, 12) - AIC:321.4262046152199
# SARIMA(0, 0, 1)x(1, 0, 1, 12) - AIC:274.47571508876075
# SARIMA(0, 0, 1)x(1, 0, 2, 12) - AIC:10.0
# SARIMA(0, 0, 1)x(1, 1, 0, 12) - AIC:28.876052238683968
# SARIMA(0, 0, 1)x(1, 1, 1, 12) - AIC:8.0
# SARIMA(0, 0, 1)x(1, 1, 2, 12) - AIC:10.0
# SARIMA(0, 0, 1)x(2, 0, 0, 12) - AIC:32.198752525962675
# SARIMA(0, 0, 1)x(2, 0, 1, 12) - AIC:34.198739156377286
# SARIMA(0, 0, 1)x(2, 0, 2, 12) - AIC:12.0
# SARIMA(0, 0, 1)x(2, 1, 0, 12) - AIC:8.0
# SARIMA(0, 0, 1)x(2, 1, 1, 12) - AIC:10.0
# SARIMA(0, 0, 1)x(2, 1, 2, 12) - AIC:12.0
# SARIMA(0, 0, 2)x(0, 0, 0, 12) - AIC:542.9292191870836
# SARIMA(0, 0, 2)x(0, 0, 1, 12) - AIC:275.10280551180773
# SARIMA(0, 0, 2)x(0, 0, 2, 12) - AIC:10.0
# SARIMA(0, 0, 2)x(0, 1, 0, 12) - AIC:252.23222125391854
# SARIMA(0, 0, 2)x(0, 1, 1, 12) - AIC:8.0
# SARIMA(0, 0, 2)x(0, 1, 2, 12) - AIC:10.0
# SARIMA(0, 0, 2)x(1, 0, 0, 12) - AIC:323.86811296023205
# SARIMA(0, 0, 2)x(1, 0, 1, 12) - AIC:276.852239898373
# SARIMA(0, 0, 2)x(1, 0, 2, 12) - AIC:12.0
# SARIMA(0, 0, 2)x(1, 1, 0, 12) - AIC:30.585209912059767
# SARIMA(0, 0, 2)x(1, 1, 1, 12) - AIC:10.0
# SARIMA(0, 0, 2)x(1, 1, 2, 12) - AIC:12.0
# SARIMA(0, 0, 2)x(2, 0, 0, 12) - AIC:34.24932925368908
# SARIMA(0, 0, 2)x(2, 0, 1, 12) - AIC:36.24932051098138
# SARIMA(0, 0, 2)x(2, 0, 2, 12) - AIC:14.0
# SARIMA(0, 0, 2)x(2, 1, 0, 12) - AIC:10.0
# SARIMA(0, 0, 2)x(2, 1, 1, 12) - AIC:12.0
# SARIMA(0, 0, 2)x(2, 1, 2, 12) - AIC:14.0
# SARIMA(0, 1, 0)x(0, 0, 0, 12) - AIC:507.75029983575087
# SARIMA(0, 1, 0)x(0, 0, 1, 12) - AIC:243.37728369895459
# SARIMA(0, 1, 0)x(0, 0, 2, 12) - AIC:6.0
# SARIMA(0, 1, 0)x(0, 1, 0, 12) - AIC:241.75001997283647
# SARIMA(0, 1, 0)x(0, 1, 1, 12) - AIC:4.0
# SARIMA(0, 1, 0)x(0, 1, 2, 12) - AIC:6.0
# SARIMA(0, 1, 0)x(0, 2, 0, 12) - AIC:2.0
# SARIMA(0, 1, 0)x(0, 2, 1, 12) - AIC:4.0
# SARIMA(0, 1, 0)x(0, 2, 2, 12) - AIC:6.0
# SARIMA(0, 1, 0)x(1, 0, 0, 12) - AIC:267.7779124943799
# SARIMA(0, 1, 0)x(1, 0, 1, 12) - AIC:244.5703519394067
# SARIMA(0, 1, 0)x(1, 0, 2, 12) - AIC:8.0
# SARIMA(0, 1, 0)x(1, 1, 0, 12) - AIC:4.0
# SARIMA(0, 1, 0)x(1, 1, 1, 12) - AIC:6.0
# SARIMA(0, 1, 0)x(1, 1, 2, 12) - AIC:8.0
# SARIMA(0, 1, 0)x(1, 2, 0, 12) - AIC:4.0
# SARIMA(0, 1, 0)x(1, 2, 1, 12) - AIC:6.0
# SARIMA(0, 1, 0)x(1, 2, 2, 12) - AIC:8.0
# SARIMA(0, 1, 0)x(2, 0, 0, 12) - AIC:6.0
# SARIMA(0, 1, 0)x(2, 0, 1, 12) - AIC:8.0
# SARIMA(0, 1, 0)x(2, 0, 2, 12) - AIC:10.0
# SARIMA(0, 1, 0)x(2, 1, 0, 12) - AIC:6.0
# SARIMA(0, 1, 0)x(2, 1, 1, 12) - AIC:8.0
# SARIMA(0, 1, 0)x(2, 1, 2, 12) - AIC:10.0
# SARIMA(0, 1, 0)x(2, 2, 0, 12) - AIC:6.0
# SARIMA(0, 1, 0)x(2, 2, 1, 12) - AIC:8.0
# SARIMA(0, 1, 0)x(2, 2, 2, 12) - AIC:10.0
# SARIMA(0, 1, 1)x(0, 0, 0, 12) - AIC:487.8676460776111
# SARIMA(0, 1, 1)x(0, 0, 1, 12) - AIC:223.5164119819893
# SARIMA(0, 1, 1)x(0, 0, 2, 12) - AIC:8.0
# SARIMA(0, 1, 1)x(0, 1, 0, 12) - AIC:220.89977083794582
# SARIMA(0, 1, 1)x(0, 1, 1, 12) - AIC:6.0
# SARIMA(0, 1, 1)x(0, 1, 2, 12) - AIC:8.0
# SARIMA(0, 1, 1)x(0, 2, 0, 12) - AIC:4.0
# SARIMA(0, 1, 1)x(0, 2, 1, 12) - AIC:6.0
# SARIMA(0, 1, 1)x(0, 2, 2, 12) - AIC:8.0
# SARIMA(0, 1, 1)x(1, 0, 0, 12) - AIC:269.4318993648327
# SARIMA(0, 1, 1)x(1, 0, 1, 12) - AIC:225.0288600472228
# SARIMA(0, 1, 1)x(1, 0, 2, 12) - AIC:10.0
# SARIMA(0, 1, 1)x(1, 1, 0, 12) - AIC:6.0
# SARIMA(0, 1, 1)x(1, 1, 1, 12) - AIC:8.0
# SARIMA(0, 1, 1)x(1, 1, 2, 12) - AIC:10.0
# SARIMA(0, 1, 1)x(1, 2, 0, 12) - AIC:6.0
# SARIMA(0, 1, 1)x(1, 2, 1, 12) - AIC:8.0
# SARIMA(0, 1, 1)x(1, 2, 2, 12) - AIC:10.0
# SARIMA(0, 1, 1)x(2, 0, 0, 12) - AIC:8.0
# SARIMA(0, 1, 1)x(2, 0, 1, 12) - AIC:10.0
# SARIMA(0, 1, 1)x(2, 0, 2, 12) - AIC:12.0
# SARIMA(0, 1, 1)x(2, 1, 0, 12) - AIC:8.0
# SARIMA(0, 1, 1)x(2, 1, 1, 12) - AIC:10.0
# SARIMA(0, 1, 1)x(2, 1, 2, 12) - AIC:12.0
# SARIMA(0, 1, 1)x(2, 2, 0, 12) - AIC:8.0
# SARIMA(0, 1, 1)x(2, 2, 1, 12) - AIC:10.0
# SARIMA(0, 1, 1)x(2, 2, 2, 12) - AIC:12.0
# SARIMA(0, 1, 2)x(0, 0, 0, 12) - AIC:462.3367014278253
# SARIMA(0, 1, 2)x(0, 0, 1, 12) - AIC:201.884821409507
# SARIMA(0, 1, 2)x(0, 0, 2, 12) - AIC:10.0
# SARIMA(0, 1, 2)x(0, 1, 0, 12) - AIC:199.84472969846584
# SARIMA(0, 1, 2)x(0, 1, 1, 12) - AIC:8.0
# SARIMA(0, 1, 2)x(0, 1, 2, 12) - AIC:10.0
# SARIMA(0, 1, 2)x(0, 2, 0, 12) - AIC:6.0
# SARIMA(0, 1, 2)x(0, 2, 1, 12) - AIC:8.0
# SARIMA(0, 1, 2)x(0, 2, 2, 12) - AIC:10.0
# SARIMA(0, 1, 2)x(1, 0, 0, 12) - AIC:264.73577282923196
# SARIMA(0, 1, 2)x(1, 0, 1, 12) - AIC:203.87221965263672
# SARIMA(0, 1, 2)x(1, 0, 2, 12) - AIC:12.0
# SARIMA(0, 1, 2)x(1, 1, 0, 12) - AIC:8.0
# SARIMA(0, 1, 2)x(1, 1, 1, 12) - AIC:10.0
# SARIMA(0, 1, 2)x(1, 1, 2, 12) - AIC:12.0
# SARIMA(0, 1, 2)x(1, 2, 0, 12) - AIC:8.0
# SARIMA(0, 1, 2)x(1, 2, 1, 12) - AIC:10.0
# SARIMA(0, 1, 2)x(1, 2, 2, 12) - AIC:12.0
# SARIMA(0, 1, 2)x(2, 0, 0, 12) - AIC:10.0
# SARIMA(0, 1, 2)x(2, 0, 1, 12) - AIC:12.0
# SARIMA(0, 1, 2)x(2, 0, 2, 12) - AIC:14.0
# SARIMA(0, 1, 2)x(2, 1, 0, 12) - AIC:10.0
# SARIMA(0, 1, 2)x(2, 1, 1, 12) - AIC:12.0
# SARIMA(0, 1, 2)x(2, 1, 2, 12) - AIC:14.0
# SARIMA(0, 1, 2)x(2, 2, 0, 12) - AIC:10.0
# SARIMA(0, 1, 2)x(2, 2, 1, 12) - AIC:12.0
# SARIMA(0, 1, 2)x(2, 2, 2, 12) - AIC:14.0
# SARIMA(0, 2, 0)x(0, 0, 0, 12) - AIC:496.1103230482061
# SARIMA(0, 2, 0)x(0, 0, 1, 12) - AIC:228.13643788460712
# SARIMA(0, 2, 0)x(0, 0, 2, 12) - AIC:6.0
# SARIMA(0, 2, 0)x(0, 1, 0, 12) - AIC:226.45332807465425
# SARIMA(0, 2, 0)x(0, 1, 1, 12) - AIC:4.0
# SARIMA(0, 2, 0)x(0, 1, 2, 12) - AIC:6.0
# SARIMA(0, 2, 0)x(0, 2, 0, 12) - AIC:2.0
# SARIMA(0, 2, 0)x(0, 2, 1, 12) - AIC:4.0
# SARIMA(0, 2, 0)x(0, 2, 2, 12) - AIC:6.0
# SARIMA(0, 2, 0)x(1, 0, 0, 12) - AIC:254.194041912505
# SARIMA(0, 2, 0)x(1, 0, 1, 12) - AIC:229.98161591683606
# SARIMA(0, 2, 0)x(1, 0, 2, 12) - AIC:8.0
# SARIMA(0, 2, 0)x(1, 1, 0, 12) - AIC:4.0
# SARIMA(0, 2, 0)x(1, 1, 1, 12) - AIC:6.0
# SARIMA(0, 2, 0)x(1, 1, 2, 12) - AIC:8.0
# SARIMA(0, 2, 0)x(1, 2, 0, 12) - AIC:4.0
# SARIMA(0, 2, 0)x(1, 2, 1, 12) - AIC:6.0
# SARIMA(0, 2, 0)x(1, 2, 2, 12) - AIC:8.0
# SARIMA(0, 2, 0)x(2, 0, 0, 12) - AIC:6.0
# SARIMA(0, 2, 0)x(2, 0, 1, 12) - AIC:8.0
# SARIMA(0, 2, 0)x(2, 0, 2, 12) - AIC:10.0
# SARIMA(0, 2, 0)x(2, 1, 0, 12) - AIC:6.0
# SARIMA(0, 2, 0)x(2, 1, 1, 12) - AIC:8.0
# SARIMA(0, 2, 0)x(2, 1, 2, 12) - AIC:10.0
# SARIMA(0, 2, 0)x(2, 2, 0, 12) - AIC:6.0
# SARIMA(0, 2, 0)x(2, 2, 1, 12) - AIC:8.0
# SARIMA(0, 2, 0)x(2, 2, 2, 12) - AIC:10.0
# SARIMA(0, 2, 1)x(0, 0, 0, 12) - AIC:468.4211772875359
# SARIMA(0, 2, 1)x(0, 0, 1, 12) - AIC:204.09740834785882
# SARIMA(0, 2, 1)x(0, 0, 2, 12) - AIC:8.0
# SARIMA(0, 2, 1)x(0, 1, 0, 12) - AIC:201.46546578118193
# SARIMA(0, 2, 1)x(0, 1, 1, 12) - AIC:6.0
# SARIMA(0, 2, 1)x(0, 1, 2, 12) - AIC:8.0
# SARIMA(0, 2, 1)x(0, 2, 0, 12) - AIC:4.0
# SARIMA(0, 2, 1)x(0, 2, 1, 12) - AIC:6.0
# SARIMA(0, 2, 1)x(0, 2, 2, 12) - AIC:8.0
# SARIMA(0, 2, 1)x(1, 0, 0, 12) - AIC:246.73234026157598
# SARIMA(0, 2, 1)x(1, 0, 1, 12) - AIC:204.7605274158744
# SARIMA(0, 2, 1)x(1, 0, 2, 12) - AIC:10.0
# SARIMA(0, 2, 1)x(1, 1, 0, 12) - AIC:6.0
# SARIMA(0, 2, 1)x(1, 1, 1, 12) - AIC:8.0
# SARIMA(0, 2, 1)x(1, 1, 2, 12) - AIC:10.0
# SARIMA(0, 2, 1)x(1, 2, 0, 12) - AIC:6.0
# SARIMA(0, 2, 1)x(1, 2, 1, 12) - AIC:8.0
# SARIMA(0, 2, 1)x(1, 2, 2, 12) - AIC:10.0
# SARIMA(0, 2, 1)x(2, 0, 0, 12) - AIC:8.0
# SARIMA(0, 2, 1)x(2, 0, 1, 12) - AIC:10.0
# SARIMA(0, 2, 1)x(2, 0, 2, 12) - AIC:12.0
# SARIMA(0, 2, 1)x(2, 1, 0, 12) - AIC:8.0
# SARIMA(0, 2, 1)x(2, 1, 1, 12) - AIC:10.0
# SARIMA(0, 2, 1)x(2, 1, 2, 12) - AIC:12.0
# SARIMA(0, 2, 1)x(2, 2, 0, 12) - AIC:8.0
# SARIMA(0, 2, 1)x(2, 2, 1, 12) - AIC:10.0
# SARIMA(0, 2, 1)x(2, 2, 2, 12) - AIC:12.0
# SARIMA(0, 2, 2)x(0, 0, 0, 12) - AIC:450.4268100931131
# SARIMA(0, 2, 2)x(0, 0, 1, 12) - AIC:185.46886724372695
# SARIMA(0, 2, 2)x(0, 0, 2, 12) - AIC:10.0
# SARIMA(0, 2, 2)x(0, 1, 0, 12) - AIC:180.1162090427672
# SARIMA(0, 2, 2)x(0, 1, 1, 12) - AIC:8.0
# SARIMA(0, 2, 2)x(0, 1, 2, 12) - AIC:10.0
# SARIMA(0, 2, 2)x(0, 2, 0, 12) - AIC:6.0
# SARIMA(0, 2, 2)x(0, 2, 1, 12) - AIC:8.0
# SARIMA(0, 2, 2)x(0, 2, 2, 12) - AIC:10.0
# SARIMA(0, 2, 2)x(1, 0, 0, 12) - AIC:250.31818221176587
# SARIMA(0, 2, 2)x(1, 0, 1, 12) - AIC:185.58155312379134
# SARIMA(0, 2, 2)x(1, 0, 2, 12) - AIC:12.0
# SARIMA(0, 2, 2)x(1, 1, 0, 12) - AIC:8.0
# SARIMA(0, 2, 2)x(1, 1, 1, 12) - AIC:10.0
# SARIMA(0, 2, 2)x(1, 1, 2, 12) - AIC:12.0
# SARIMA(0, 2, 2)x(1, 2, 0, 12) - AIC:8.0
# SARIMA(0, 2, 2)x(1, 2, 1, 12) - AIC:10.0
# SARIMA(0, 2, 2)x(1, 2, 2, 12) - AIC:12.0
# SARIMA(0, 2, 2)x(2, 0, 0, 12) - AIC:10.0
# SARIMA(0, 2, 2)x(2, 0, 1, 12) - AIC:12.0
# SARIMA(0, 2, 2)x(2, 0, 2, 12) - AIC:14.0
# SARIMA(0, 2, 2)x(2, 1, 0, 12) - AIC:10.0
# SARIMA(0, 2, 2)x(2, 1, 1, 12) - AIC:12.0
# SARIMA(0, 2, 2)x(2, 1, 2, 12) - AIC:14.0
# SARIMA(0, 2, 2)x(2, 2, 0, 12) - AIC:10.0
# SARIMA(0, 2, 2)x(2, 2, 1, 12) - AIC:12.0
# SARIMA(0, 2, 2)x(2, 2, 2, 12) - AIC:14.0
# SARIMA(1, 0, 0)x(0, 0, 0, 12) - AIC:529.0926606899473
# SARIMA(1, 0, 0)x(0, 0, 1, 12) - AIC:268.86698099468975
# SARIMA(1, 0, 0)x(0, 0, 2, 12) - AIC:8.0
# SARIMA(1, 0, 0)x(0, 1, 0, 12) - AIC:267.50452454493814
# SARIMA(1, 0, 0)x(0, 1, 1, 12) - AIC:6.0
# SARIMA(1, 0, 0)x(0, 1, 2, 12) - AIC:8.0
# SARIMA(1, 0, 0)x(1, 0, 0, 12) - AIC:268.86965621417835
# SARIMA(1, 0, 0)x(1, 0, 1, 12) - AIC:269.8204120484666
# SARIMA(1, 0, 0)x(1, 0, 2, 12) - AIC:10.0
# SARIMA(1, 0, 0)x(1, 1, 0, 12) - AIC:6.0
# SARIMA(1, 0, 0)x(1, 1, 1, 12) - AIC:8.0
# SARIMA(1, 0, 0)x(1, 1, 2, 12) - AIC:10.0
# SARIMA(1, 0, 0)x(2, 0, 0, 12) - AIC:8.0
# SARIMA(1, 0, 0)x(2, 0, 1, 12) - AIC:10.0
# SARIMA(1, 0, 0)x(2, 0, 2, 12) - AIC:12.0
# SARIMA(1, 0, 0)x(2, 1, 0, 12) - AIC:8.0
# SARIMA(1, 0, 0)x(2, 1, 1, 12) - AIC:10.0
# SARIMA(1, 0, 0)x(2, 1, 2, 12) - AIC:12.0
# SARIMA(1, 0, 1)x(0, 0, 0, 12) - AIC:509.9305379949461
# SARIMA(1, 0, 1)x(0, 0, 1, 12) - AIC:244.820816974898
# SARIMA(1, 0, 1)x(0, 0, 2, 12) - AIC:10.0
# SARIMA(1, 0, 1)x(0, 1, 0, 12) - AIC:243.59088207086214
# SARIMA(1, 0, 1)x(0, 1, 1, 12) - AIC:8.0
# SARIMA(1, 0, 1)x(0, 1, 2, 12) - AIC:10.0
# SARIMA(1, 0, 1)x(1, 0, 0, 12) - AIC:269.10905994576126
# SARIMA(1, 0, 1)x(1, 0, 1, 12) - AIC:245.70441248351378
# SARIMA(1, 0, 1)x(1, 0, 2, 12) - AIC:12.0
# SARIMA(1, 0, 1)x(1, 1, 0, 12) - AIC:8.0
# SARIMA(1, 0, 1)x(1, 1, 1, 12) - AIC:10.0
# SARIMA(1, 0, 1)x(1, 1, 2, 12) - AIC:12.0
# SARIMA(1, 0, 1)x(2, 0, 0, 12) - AIC:10.0
# SARIMA(1, 0, 1)x(2, 0, 1, 12) - AIC:12.0
# SARIMA(1, 0, 1)x(2, 0, 2, 12) - AIC:14.0
# SARIMA(1, 0, 1)x(2, 1, 0, 12) - AIC:10.0
# SARIMA(1, 0, 1)x(2, 1, 1, 12) - AIC:12.0
# SARIMA(1, 0, 1)x(2, 1, 2, 12) - AIC:14.0
# SARIMA(1, 0, 2)x(0, 0, 0, 12) - AIC:484.0478395852423
# SARIMA(1, 0, 2)x(0, 0, 1, 12) - AIC:224.8239978606494
# SARIMA(1, 0, 2)x(0, 0, 2, 12) - AIC:12.0
# SARIMA(1, 0, 2)x(0, 1, 0, 12) - AIC:222.36483202038434
# SARIMA(1, 0, 2)x(0, 1, 1, 12) - AIC:10.0
# SARIMA(1, 0, 2)x(0, 1, 2, 12) - AIC:12.0
# SARIMA(1, 0, 2)x(1, 0, 0, 12) - AIC:265.4979082623389
# SARIMA(1, 0, 2)x(1, 0, 1, 12) - AIC:225.82154213445313
# SARIMA(1, 0, 2)x(1, 0, 2, 12) - AIC:14.0
# SARIMA(1, 0, 2)x(1, 1, 0, 12) - AIC:10.0
# SARIMA(1, 0, 2)x(1, 1, 1, 12) - AIC:12.0
# SARIMA(1, 0, 2)x(1, 1, 2, 12) - AIC:14.0
# SARIMA(1, 0, 2)x(2, 0, 0, 12) - AIC:12.0
# SARIMA(1, 0, 2)x(2, 0, 1, 12) - AIC:14.0
# SARIMA(1, 0, 2)x(2, 0, 2, 12) - AIC:16.0
# SARIMA(1, 0, 2)x(2, 1, 0, 12) - AIC:12.0
# SARIMA(1, 0, 2)x(2, 1, 1, 12) - AIC:14.0
# SARIMA(1, 0, 2)x(2, 1, 2, 12) - AIC:16.0
# SARIMA(1, 1, 0)x(0, 0, 0, 12) - AIC:508.36488757100045
# SARIMA(1, 1, 0)x(0, 0, 1, 12) - AIC:245.14256972961957
# SARIMA(1, 1, 0)x(0, 0, 2, 12) - AIC:8.0
# SARIMA(1, 1, 0)x(0, 1, 0, 12) - AIC:243.1084021186686
# SARIMA(1, 1, 0)x(0, 1, 1, 12) - AIC:6.0
# SARIMA(1, 1, 0)x(0, 1, 2, 12) - AIC:8.0
# SARIMA(1, 1, 0)x(0, 2, 0, 12) - AIC:4.0
# SARIMA(1, 1, 0)x(0, 2, 1, 12) - AIC:6.0
# SARIMA(1, 1, 0)x(0, 2, 2, 12) - AIC:8.0
# SARIMA(1, 1, 0)x(1, 0, 0, 12) - AIC:245.12782196898235
# SARIMA(1, 1, 0)x(1, 0, 1, 12) - AIC:246.37066438295759
# SARIMA(1, 1, 0)x(1, 0, 2, 12) - AIC:10.0
# SARIMA(1, 1, 0)x(1, 1, 0, 12) - AIC:6.0
# SARIMA(1, 1, 0)x(1, 1, 1, 12) - AIC:8.0
# SARIMA(1, 1, 0)x(1, 1, 2, 12) - AIC:10.0
# SARIMA(1, 1, 0)x(1, 2, 0, 12) - AIC:6.0
# SARIMA(1, 1, 0)x(1, 2, 1, 12) - AIC:8.0
# SARIMA(1, 1, 0)x(1, 2, 2, 12) - AIC:10.0
# SARIMA(1, 1, 0)x(2, 0, 0, 12) - AIC:8.0
# SARIMA(1, 1, 0)x(2, 0, 1, 12) - AIC:10.0
# SARIMA(1, 1, 0)x(2, 0, 2, 12) - AIC:12.0
# SARIMA(1, 1, 0)x(2, 1, 0, 12) - AIC:8.0
# SARIMA(1, 1, 0)x(2, 1, 1, 12) - AIC:10.0
# SARIMA(1, 1, 0)x(2, 1, 2, 12) - AIC:12.0
# SARIMA(1, 1, 0)x(2, 2, 0, 12) - AIC:8.0
# SARIMA(1, 1, 0)x(2, 2, 1, 12) - AIC:10.0
# SARIMA(1, 1, 0)x(2, 2, 2, 12) - AIC:12.0
# SARIMA(1, 1, 1)x(0, 0, 0, 12) - AIC:488.73943512866634
# SARIMA(1, 1, 1)x(0, 0, 1, 12) - AIC:223.96904108696387
# SARIMA(1, 1, 1)x(0, 0, 2, 12) - AIC:10.0
# SARIMA(1, 1, 1)x(0, 1, 0, 12) - AIC:222.85065075165394
# SARIMA(1, 1, 1)x(0, 1, 1, 12) - AIC:8.0
# SARIMA(1, 1, 1)x(0, 1, 2, 12) - AIC:10.0
# SARIMA(1, 1, 1)x(0, 2, 0, 12) - AIC:6.0
# SARIMA(1, 1, 1)x(0, 2, 1, 12) - AIC:8.0
# SARIMA(1, 1, 1)x(0, 2, 2, 12) - AIC:10.0
# SARIMA(1, 1, 1)x(1, 0, 0, 12) - AIC:247.32229930486017
# SARIMA(1, 1, 1)x(1, 0, 1, 12) - AIC:224.87660014140812
# SARIMA(1, 1, 1)x(1, 0, 2, 12) - AIC:12.0
# SARIMA(1, 1, 1)x(1, 1, 0, 12) - AIC:8.0
# SARIMA(1, 1, 1)x(1, 1, 1, 12) - AIC:10.0
# SARIMA(1, 1, 1)x(1, 1, 2, 12) - AIC:12.0
# SARIMA(1, 1, 1)x(1, 2, 0, 12) - AIC:8.0
# SARIMA(1, 1, 1)x(1, 2, 1, 12) - AIC:10.0
# SARIMA(1, 1, 1)x(1, 2, 2, 12) - AIC:12.0
# SARIMA(1, 1, 1)x(2, 0, 0, 12) - AIC:10.0
# SARIMA(1, 1, 1)x(2, 0, 1, 12) - AIC:12.0
# SARIMA(1, 1, 1)x(2, 0, 2, 12) - AIC:14.0
# SARIMA(1, 1, 1)x(2, 1, 0, 12) - AIC:10.0
# SARIMA(1, 1, 1)x(2, 1, 1, 12) - AIC:12.0
# SARIMA(1, 1, 1)x(2, 1, 2, 12) - AIC:14.0
# SARIMA(1, 1, 1)x(2, 2, 0, 12) - AIC:10.0
# SARIMA(1, 1, 1)x(2, 2, 1, 12) - AIC:12.0
# SARIMA(1, 1, 1)x(2, 2, 2, 12) - AIC:14.0
# SARIMA(1, 1, 2)x(0, 0, 0, 12) - AIC:462.71319910591404
# SARIMA(1, 1, 2)x(0, 0, 1, 12) - AIC:203.32598384533887
# SARIMA(1, 1, 2)x(0, 0, 2, 12) - AIC:12.0
# SARIMA(1, 1, 2)x(0, 1, 0, 12) - AIC:201.26002697419608
# SARIMA(1, 1, 2)x(0, 1, 1, 12) - AIC:10.0
# SARIMA(1, 1, 2)x(0, 1, 2, 12) - AIC:12.0
# SARIMA(1, 1, 2)x(0, 2, 0, 12) - AIC:8.0
# SARIMA(1, 1, 2)x(0, 2, 1, 12) - AIC:10.0
# SARIMA(1, 1, 2)x(0, 2, 2, 12) - AIC:12.0
# SARIMA(1, 1, 2)x(1, 0, 0, 12) - AIC:245.1016609944393
# SARIMA(1, 1, 2)x(1, 0, 1, 12) - AIC:205.32059328174182
# SARIMA(1, 1, 2)x(1, 0, 2, 12) - AIC:14.0
# SARIMA(1, 1, 2)x(1, 1, 0, 12) - AIC:10.0
# SARIMA(1, 1, 2)x(1, 1, 1, 12) - AIC:12.0
# SARIMA(1, 1, 2)x(1, 1, 2, 12) - AIC:14.0
# SARIMA(1, 1, 2)x(1, 2, 0, 12) - AIC:10.0
# SARIMA(1, 1, 2)x(1, 2, 1, 12) - AIC:12.0
# SARIMA(1, 1, 2)x(1, 2, 2, 12) - AIC:14.0
# SARIMA(1, 1, 2)x(2, 0, 0, 12) - AIC:12.0
# SARIMA(1, 1, 2)x(2, 0, 1, 12) - AIC:14.0
# SARIMA(1, 1, 2)x(2, 0, 2, 12) - AIC:16.0
# SARIMA(1, 1, 2)x(2, 1, 0, 12) - AIC:12.0
# SARIMA(1, 1, 2)x(2, 1, 1, 12) - AIC:14.0
# SARIMA(1, 1, 2)x(2, 1, 2, 12) - AIC:16.0
# SARIMA(1, 1, 2)x(2, 2, 0, 12) - AIC:12.0
# SARIMA(1, 1, 2)x(2, 2, 1, 12) - AIC:14.0
# SARIMA(1, 1, 2)x(2, 2, 2, 12) - AIC:16.0
# SARIMA(1, 2, 0)x(0, 0, 0, 12) - AIC:487.9710140489417
# SARIMA(1, 2, 0)x(0, 0, 1, 12) - AIC:224.74582750338604
# SARIMA(1, 2, 0)x(0, 0, 2, 12) - AIC:8.0
# SARIMA(1, 2, 0)x(0, 1, 0, 12) - AIC:222.9660838769346
# SARIMA(1, 2, 0)x(0, 1, 1, 12) - AIC:6.0
# SARIMA(1, 2, 0)x(0, 1, 2, 12) - AIC:8.0
# SARIMA(1, 2, 0)x(0, 2, 0, 12) - AIC:4.0
# SARIMA(1, 2, 0)x(0, 2, 1, 12) - AIC:6.0
# SARIMA(1, 2, 0)x(0, 2, 2, 12) - AIC:8.0
# SARIMA(1, 2, 0)x(1, 0, 0, 12) - AIC:224.74291945869322
# SARIMA(1, 2, 0)x(1, 0, 1, 12) - AIC:226.4875738313598
# SARIMA(1, 2, 0)x(1, 0, 2, 12) - AIC:10.0
# SARIMA(1, 2, 0)x(1, 1, 0, 12) - AIC:6.0
# SARIMA(1, 2, 0)x(1, 1, 1, 12) - AIC:8.0
# SARIMA(1, 2, 0)x(1, 1, 2, 12) - AIC:10.0
# SARIMA(1, 2, 0)x(1, 2, 0, 12) - AIC:6.0
# SARIMA(1, 2, 0)x(1, 2, 1, 12) - AIC:8.0
# SARIMA(1, 2, 0)x(1, 2, 2, 12) - AIC:10.0
# SARIMA(1, 2, 0)x(2, 0, 0, 12) - AIC:8.0
# SARIMA(1, 2, 0)x(2, 0, 1, 12) - AIC:10.0
# SARIMA(1, 2, 0)x(2, 0, 2, 12) - AIC:12.0
# SARIMA(1, 2, 0)x(2, 1, 0, 12) - AIC:8.0
# SARIMA(1, 2, 0)x(2, 1, 1, 12) - AIC:10.0
# SARIMA(1, 2, 0)x(2, 1, 2, 12) - AIC:12.0
# SARIMA(1, 2, 0)x(2, 2, 0, 12) - AIC:8.0
# SARIMA(1, 2, 0)x(2, 2, 1, 12) - AIC:10.0
# SARIMA(1, 2, 0)x(2, 2, 2, 12) - AIC:12.0
# SARIMA(1, 2, 1)x(0, 0, 0, 12) - AIC:469.04373926561345
# SARIMA(1, 2, 1)x(0, 0, 1, 12) - AIC:204.79329668435295
# SARIMA(1, 2, 1)x(0, 0, 2, 12) - AIC:10.0
# SARIMA(1, 2, 1)x(0, 1, 0, 12) - AIC:203.12698856503522
# SARIMA(1, 2, 1)x(0, 1, 1, 12) - AIC:8.0
# SARIMA(1, 2, 1)x(0, 1, 2, 12) - AIC:10.0
# SARIMA(1, 2, 1)x(0, 2, 0, 12) - AIC:6.0
# SARIMA(1, 2, 1)x(0, 2, 1, 12) - AIC:8.0
# SARIMA(1, 2, 1)x(0, 2, 2, 12) - AIC:10.0
# SARIMA(1, 2, 1)x(1, 0, 0, 12) - AIC:227.00962818323865
# SARIMA(1, 2, 1)x(1, 0, 1, 12) - AIC:206.58577206868904
# SARIMA(1, 2, 1)x(1, 0, 2, 12) - AIC:12.0
# SARIMA(1, 2, 1)x(1, 1, 0, 12) - AIC:8.0
# SARIMA(1, 2, 1)x(1, 1, 1, 12) - AIC:10.0
# SARIMA(1, 2, 1)x(1, 1, 2, 12) - AIC:12.0
# SARIMA(1, 2, 1)x(1, 2, 0, 12) - AIC:8.0
# SARIMA(1, 2, 1)x(1, 2, 1, 12) - AIC:10.0
# SARIMA(1, 2, 1)x(1, 2, 2, 12) - AIC:12.0
# SARIMA(1, 2, 1)x(2, 0, 0, 12) - AIC:10.0
# SARIMA(1, 2, 1)x(2, 0, 1, 12) - AIC:12.0
# SARIMA(1, 2, 1)x(2, 0, 2, 12) - AIC:14.0
# SARIMA(1, 2, 1)x(2, 1, 0, 12) - AIC:10.0
# SARIMA(1, 2, 1)x(2, 1, 1, 12) - AIC:12.0
# SARIMA(1, 2, 1)x(2, 1, 2, 12) - AIC:14.0
# SARIMA(1, 2, 1)x(2, 2, 0, 12) - AIC:10.0
# SARIMA(1, 2, 1)x(2, 2, 1, 12) - AIC:12.0
# SARIMA(1, 2, 1)x(2, 2, 2, 12) - AIC:14.0
# SARIMA(1, 2, 2)x(0, 0, 0, 12) - AIC:448.4632845680419
# SARIMA(1, 2, 2)x(0, 0, 1, 12) - AIC:183.52910712159184
# SARIMA(1, 2, 2)x(0, 0, 2, 12) - AIC:12.0
# SARIMA(1, 2, 2)x(0, 1, 0, 12) - AIC:178.77882611721412
# SARIMA(1, 2, 2)x(0, 1, 1, 12) - AIC:10.0
# SARIMA(1, 2, 2)x(0, 1, 2, 12) - AIC:12.0
# SARIMA(1, 2, 2)x(0, 2, 0, 12) - AIC:8.0
# SARIMA(1, 2, 2)x(0, 2, 1, 12) - AIC:10.0
# SARIMA(1, 2, 2)x(0, 2, 2, 12) - AIC:12.0
# SARIMA(1, 2, 2)x(1, 0, 0, 12) - AIC:227.73721655739388
# SARIMA(1, 2, 2)x(1, 0, 1, 12) - AIC:185.46835915722843
# SARIMA(1, 2, 2)x(1, 0, 2, 12) - AIC:14.0
# SARIMA(1, 2, 2)x(1, 1, 0, 12) - AIC:10.0
# SARIMA(1, 2, 2)x(1, 1, 1, 12) - AIC:12.0
# SARIMA(1, 2, 2)x(1, 1, 2, 12) - AIC:14.0
# SARIMA(1, 2, 2)x(1, 2, 0, 12) - AIC:10.0
# SARIMA(1, 2, 2)x(1, 2, 1, 12) - AIC:12.0
# SARIMA(1, 2, 2)x(1, 2, 2, 12) - AIC:14.0
# SARIMA(1, 2, 2)x(2, 0, 0, 12) - AIC:12.0
# SARIMA(1, 2, 2)x(2, 0, 1, 12) - AIC:14.0
# SARIMA(1, 2, 2)x(2, 0, 2, 12) - AIC:16.0
# SARIMA(1, 2, 2)x(2, 1, 0, 12) - AIC:12.0
# SARIMA(1, 2, 2)x(2, 1, 1, 12) - AIC:14.0
# SARIMA(1, 2, 2)x(2, 1, 2, 12) - AIC:16.0
# SARIMA(1, 2, 2)x(2, 2, 0, 12) - AIC:12.0
# SARIMA(1, 2, 2)x(2, 2, 1, 12) - AIC:14.0
# SARIMA(1, 2, 2)x(2, 2, 2, 12) - AIC:16.0
# SARIMA(2, 0, 0)x(0, 0, 0, 12) - AIC:509.67428729774633
# SARIMA(2, 0, 0)x(0, 0, 1, 12) - AIC:268.30140700043074
# SARIMA(2, 0, 0)x(0, 0, 2, 12) - AIC:10.0
# SARIMA(2, 0, 0)x(0, 1, 0, 12) - AIC:243.42250451750022
# SARIMA(2, 0, 0)x(0, 1, 1, 12) - AIC:8.0
# SARIMA(2, 0, 0)x(0, 1, 2, 12) - AIC:10.0
# SARIMA(2, 0, 0)x(1, 0, 0, 12) - AIC:244.33452219937658
# SARIMA(2, 0, 0)x(1, 0, 1, 12) - AIC:245.1752557028042
# SARIMA(2, 0, 0)x(1, 0, 2, 12) - AIC:12.0
# SARIMA(2, 0, 0)x(1, 1, 0, 12) - AIC:8.0
# SARIMA(2, 0, 0)x(1, 1, 1, 12) - AIC:10.0
# SARIMA(2, 0, 0)x(1, 1, 2, 12) - AIC:12.0
# SARIMA(2, 0, 0)x(2, 0, 0, 12) - AIC:10.0
# SARIMA(2, 0, 0)x(2, 0, 1, 12) - AIC:12.0
# SARIMA(2, 0, 0)x(2, 0, 2, 12) - AIC:14.0
# SARIMA(2, 0, 0)x(2, 1, 0, 12) - AIC:10.0
# SARIMA(2, 0, 0)x(2, 1, 1, 12) - AIC:12.0
# SARIMA(2, 0, 0)x(2, 1, 2, 12) - AIC:14.0
# SARIMA(2, 0, 1)x(0, 0, 0, 12) - AIC:527.8314588850529
# SARIMA(2, 0, 1)x(0, 0, 1, 12) - AIC:245.27577572731502
# SARIMA(2, 0, 1)x(0, 0, 2, 12) - AIC:12.0
# SARIMA(2, 0, 1)x(0, 1, 0, 12) - AIC:248.73077724733676
# SARIMA(2, 0, 1)x(0, 1, 1, 12) - AIC:10.0
# SARIMA(2, 0, 1)x(0, 1, 2, 12) - AIC:12.0
# SARIMA(2, 0, 1)x(1, 0, 0, 12) - AIC:245.2571281525136
# SARIMA(2, 0, 1)x(1, 0, 1, 12) - AIC:246.5493993501811
# SARIMA(2, 0, 1)x(1, 0, 2, 12) - AIC:14.0
# SARIMA(2, 0, 1)x(1, 1, 0, 12) - AIC:10.0
# SARIMA(2, 0, 1)x(1, 1, 1, 12) - AIC:12.0
# SARIMA(2, 0, 1)x(1, 1, 2, 12) - AIC:14.0
# SARIMA(2, 0, 1)x(2, 0, 0, 12) - AIC:12.0
# SARIMA(2, 0, 1)x(2, 0, 1, 12) - AIC:14.0
# SARIMA(2, 0, 1)x(2, 0, 2, 12) - AIC:16.0
# SARIMA(2, 0, 1)x(2, 1, 0, 12) - AIC:12.0
# SARIMA(2, 0, 1)x(2, 1, 1, 12) - AIC:14.0
# SARIMA(2, 0, 1)x(2, 1, 2, 12) - AIC:16.0
# SARIMA(2, 0, 2)x(0, 0, 0, 12) - AIC:484.4893201351564
# SARIMA(2, 0, 2)x(0, 0, 1, 12) - AIC:224.14787179419858
# SARIMA(2, 0, 2)x(0, 0, 2, 12) - AIC:14.0
# SARIMA(2, 0, 2)x(0, 1, 0, 12) - AIC:223.32442012520357
# SARIMA(2, 0, 2)x(0, 1, 1, 12) - AIC:12.0
# SARIMA(2, 0, 2)x(0, 1, 2, 12) - AIC:14.0
# SARIMA(2, 0, 2)x(1, 0, 0, 12) - AIC:245.51688450990332
# SARIMA(2, 0, 2)x(1, 0, 1, 12) - AIC:226.09244115155394
# SARIMA(2, 0, 2)x(1, 0, 2, 12) - AIC:16.0
# SARIMA(2, 0, 2)x(1, 1, 0, 12) - AIC:12.0
# SARIMA(2, 0, 2)x(1, 1, 1, 12) - AIC:14.0
# SARIMA(2, 0, 2)x(1, 1, 2, 12) - AIC:16.0
# SARIMA(2, 0, 2)x(2, 0, 0, 12) - AIC:14.0
# SARIMA(2, 0, 2)x(2, 0, 1, 12) - AIC:16.0
# SARIMA(2, 0, 2)x(2, 0, 2, 12) - AIC:18.0
# SARIMA(2, 0, 2)x(2, 1, 0, 12) - AIC:14.0
# SARIMA(2, 0, 2)x(2, 1, 1, 12) - AIC:16.0
# SARIMA(2, 0, 2)x(2, 1, 2, 12) - AIC:18.0
# SARIMA(2, 1, 0)x(0, 0, 0, 12) - AIC:486.46676599177135
# SARIMA(2, 1, 0)x(0, 0, 1, 12) - AIC:246.71544000487202
# SARIMA(2, 1, 0)x(0, 0, 2, 12) - AIC:10.0
# SARIMA(2, 1, 0)x(0, 1, 0, 12) - AIC:222.31834515475367
# SARIMA(2, 1, 0)x(0, 1, 1, 12) - AIC:8.0
# SARIMA(2, 1, 0)x(0, 1, 2, 12) - AIC:10.0
# SARIMA(2, 1, 0)x(0, 2, 0, 12) - AIC:6.0
# SARIMA(2, 1, 0)x(0, 2, 1, 12) - AIC:8.0
# SARIMA(2, 1, 0)x(0, 2, 2, 12) - AIC:10.0
# SARIMA(2, 1, 0)x(1, 0, 0, 12) - AIC:224.48285161265534
# SARIMA(2, 1, 0)x(1, 0, 1, 12) - AIC:226.00101945183783
# SARIMA(2, 1, 0)x(1, 0, 2, 12) - AIC:12.0
# SARIMA(2, 1, 0)x(1, 1, 0, 12) - AIC:8.0
# SARIMA(2, 1, 0)x(1, 1, 1, 12) - AIC:10.0
# SARIMA(2, 1, 0)x(1, 1, 2, 12) - AIC:12.0
# SARIMA(2, 1, 0)x(1, 2, 0, 12) - AIC:8.0
# SARIMA(2, 1, 0)x(1, 2, 1, 12) - AIC:10.0
# SARIMA(2, 1, 0)x(1, 2, 2, 12) - AIC:12.0
# SARIMA(2, 1, 0)x(2, 0, 0, 12) - AIC:10.0
# SARIMA(2, 1, 0)x(2, 0, 1, 12) - AIC:12.0
# SARIMA(2, 1, 0)x(2, 0, 2, 12) - AIC:14.0
# SARIMA(2, 1, 0)x(2, 1, 0, 12) - AIC:10.0
# SARIMA(2, 1, 0)x(2, 1, 1, 12) - AIC:12.0
# SARIMA(2, 1, 0)x(2, 1, 2, 12) - AIC:14.0
# SARIMA(2, 1, 0)x(2, 2, 0, 12) - AIC:10.0
# SARIMA(2, 1, 0)x(2, 2, 1, 12) - AIC:12.0
# SARIMA(2, 1, 0)x(2, 2, 2, 12) - AIC:14.0
# SARIMA(2, 1, 1)x(0, 0, 0, 12) - AIC:488.2310341657306
# SARIMA(2, 1, 1)x(0, 0, 1, 12) - AIC:226.51299426381075
# SARIMA(2, 1, 1)x(0, 0, 2, 12) - AIC:12.0
# SARIMA(2, 1, 1)x(0, 1, 0, 12) - AIC:223.87994944219506
# SARIMA(2, 1, 1)x(0, 1, 1, 12) - AIC:10.0
# SARIMA(2, 1, 1)x(0, 1, 2, 12) - AIC:12.0
# SARIMA(2, 1, 1)x(0, 2, 0, 12) - AIC:8.0
# SARIMA(2, 1, 1)x(0, 2, 1, 12) - AIC:10.0
# SARIMA(2, 1, 1)x(0, 2, 2, 12) - AIC:12.0
# SARIMA(2, 1, 1)x(1, 0, 0, 12) - AIC:226.49594955875085
# SARIMA(2, 1, 1)x(1, 0, 1, 12) - AIC:228.04213855100656
# SARIMA(2, 1, 1)x(1, 0, 2, 12) - AIC:14.0
# SARIMA(2, 1, 1)x(1, 1, 0, 12) - AIC:10.0
# SARIMA(2, 1, 1)x(1, 1, 1, 12) - AIC:12.0
# SARIMA(2, 1, 1)x(1, 1, 2, 12) - AIC:14.0
# SARIMA(2, 1, 1)x(1, 2, 0, 12) - AIC:10.0
# SARIMA(2, 1, 1)x(1, 2, 1, 12) - AIC:12.0
# SARIMA(2, 1, 1)x(1, 2, 2, 12) - AIC:14.0
# SARIMA(2, 1, 1)x(2, 0, 0, 12) - AIC:12.0
# SARIMA(2, 1, 1)x(2, 0, 1, 12) - AIC:14.0
# SARIMA(2, 1, 1)x(2, 0, 2, 12) - AIC:16.0
# SARIMA(2, 1, 1)x(2, 1, 0, 12) - AIC:12.0
# SARIMA(2, 1, 1)x(2, 1, 1, 12) - AIC:14.0
# SARIMA(2, 1, 1)x(2, 1, 2, 12) - AIC:16.0
# SARIMA(2, 1, 1)x(2, 2, 0, 12) - AIC:12.0
# SARIMA(2, 1, 1)x(2, 2, 1, 12) - AIC:14.0
# SARIMA(2, 1, 1)x(2, 2, 2, 12) - AIC:16.0
# SARIMA(2, 1, 2)x(0, 0, 0, 12) - AIC:463.98061835934305
# SARIMA(2, 1, 2)x(0, 0, 1, 12) - AIC:205.2334497882296
# SARIMA(2, 1, 2)x(0, 0, 2, 12) - AIC:14.0
# SARIMA(2, 1, 2)x(0, 1, 0, 12) - AIC:199.10886994221158
# SARIMA(2, 1, 2)x(0, 1, 1, 12) - AIC:12.0
# SARIMA(2, 1, 2)x(0, 1, 2, 12) - AIC:14.0
# SARIMA(2, 1, 2)x(0, 2, 0, 12) - AIC:10.0
# SARIMA(2, 1, 2)x(0, 2, 1, 12) - AIC:12.0
# SARIMA(2, 1, 2)x(0, 2, 2, 12) - AIC:14.0
# SARIMA(2, 1, 2)x(1, 0, 0, 12) - AIC:225.60195702851013
# SARIMA(2, 1, 2)x(1, 0, 1, 12) - AIC:207.23325242873608
# SARIMA(2, 1, 2)x(1, 0, 2, 12) - AIC:16.0
# SARIMA(2, 1, 2)x(1, 1, 0, 12) - AIC:12.0
# SARIMA(2, 1, 2)x(1, 1, 1, 12) - AIC:14.0
# SARIMA(2, 1, 2)x(1, 1, 2, 12) - AIC:16.0
# SARIMA(2, 1, 2)x(1, 2, 0, 12) - AIC:12.0
# SARIMA(2, 1, 2)x(1, 2, 1, 12) - AIC:14.0
# SARIMA(2, 1, 2)x(1, 2, 2, 12) - AIC:16.0
# SARIMA(2, 1, 2)x(2, 0, 0, 12) - AIC:14.0
# SARIMA(2, 1, 2)x(2, 0, 1, 12) - AIC:16.0
# SARIMA(2, 1, 2)x(2, 0, 2, 12) - AIC:18.0
# SARIMA(2, 1, 2)x(2, 1, 0, 12) - AIC:14.0
# SARIMA(2, 1, 2)x(2, 1, 1, 12) - AIC:16.0
# SARIMA(2, 1, 2)x(2, 1, 2, 12) - AIC:18.0
# SARIMA(2, 1, 2)x(2, 2, 0, 12) - AIC:14.0
# SARIMA(2, 1, 2)x(2, 2, 1, 12) - AIC:16.0
# SARIMA(2, 1, 2)x(2, 2, 2, 12) - AIC:18.0
# SARIMA(2, 2, 0)x(0, 0, 0, 12) - AIC:468.9412886906582
# SARIMA(2, 2, 0)x(0, 0, 1, 12) - AIC:226.8074719761003
# SARIMA(2, 2, 0)x(0, 0, 2, 12) - AIC:10.0
# SARIMA(2, 2, 0)x(0, 1, 0, 12) - AIC:202.91209611493818
# SARIMA(2, 2, 0)x(0, 1, 1, 12) - AIC:8.0
# SARIMA(2, 2, 0)x(0, 1, 2, 12) - AIC:10.0
# SARIMA(2, 2, 0)x(0, 2, 0, 12) - AIC:6.0
# SARIMA(2, 2, 0)x(0, 2, 1, 12) - AIC:8.0
# SARIMA(2, 2, 0)x(0, 2, 2, 12) - AIC:10.0
# SARIMA(2, 2, 0)x(1, 0, 0, 12) - AIC:204.52975746622047
# SARIMA(2, 2, 0)x(1, 0, 1, 12) - AIC:206.31397425634816
# SARIMA(2, 2, 0)x(1, 0, 2, 12) - AIC:12.0
# SARIMA(2, 2, 0)x(1, 1, 0, 12) - AIC:8.0
# SARIMA(2, 2, 0)x(1, 1, 1, 12) - AIC:10.0
# SARIMA(2, 2, 0)x(1, 1, 2, 12) - AIC:12.0
# SARIMA(2, 2, 0)x(1, 2, 0, 12) - AIC:8.0
# SARIMA(2, 2, 0)x(1, 2, 1, 12) - AIC:10.0
# SARIMA(2, 2, 0)x(1, 2, 2, 12) - AIC:12.0
# SARIMA(2, 2, 0)x(2, 0, 0, 12) - AIC:10.0
# SARIMA(2, 2, 0)x(2, 0, 1, 12) - AIC:12.0
# SARIMA(2, 2, 0)x(2, 0, 2, 12) - AIC:14.0
# SARIMA(2, 2, 0)x(2, 1, 0, 12) - AIC:10.0
# SARIMA(2, 2, 0)x(2, 1, 1, 12) - AIC:12.0
# SARIMA(2, 2, 0)x(2, 1, 2, 12) - AIC:14.0
# SARIMA(2, 2, 0)x(2, 2, 0, 12) - AIC:10.0
# SARIMA(2, 2, 0)x(2, 2, 1, 12) - AIC:12.0
# SARIMA(2, 2, 0)x(2, 2, 2, 12) - AIC:14.0
# SARIMA(2, 2, 1)x(0, 0, 0, 12) - AIC:465.5575244888495
# SARIMA(2, 2, 1)x(0, 0, 1, 12) - AIC:203.7790408180692
# SARIMA(2, 2, 1)x(0, 0, 2, 12) - AIC:12.0
# SARIMA(2, 2, 1)x(0, 1, 0, 12) - AIC:203.19554819810196
# SARIMA(2, 2, 1)x(0, 1, 1, 12) - AIC:10.0
# SARIMA(2, 2, 1)x(0, 1, 2, 12) - AIC:12.0
# SARIMA(2, 2, 1)x(0, 2, 0, 12) - AIC:8.0
# SARIMA(2, 2, 1)x(0, 2, 1, 12) - AIC:10.0
# SARIMA(2, 2, 1)x(0, 2, 2, 12) - AIC:12.0
# SARIMA(2, 2, 1)x(1, 0, 0, 12) - AIC:204.10853064044008
# SARIMA(2, 2, 1)x(1, 0, 1, 12) - AIC:205.73694187337668
# SARIMA(2, 2, 1)x(1, 0, 2, 12) - AIC:14.0
# SARIMA(2, 2, 1)x(1, 1, 0, 12) - AIC:10.0
# SARIMA(2, 2, 1)x(1, 1, 1, 12) - AIC:12.0
# SARIMA(2, 2, 1)x(1, 1, 2, 12) - AIC:14.0
# SARIMA(2, 2, 1)x(1, 2, 0, 12) - AIC:10.0
# SARIMA(2, 2, 1)x(1, 2, 1, 12) - AIC:12.0
# SARIMA(2, 2, 1)x(1, 2, 2, 12) - AIC:14.0
# SARIMA(2, 2, 1)x(2, 0, 0, 12) - AIC:12.0
# SARIMA(2, 2, 1)x(2, 0, 1, 12) - AIC:14.0
# SARIMA(2, 2, 1)x(2, 0, 2, 12) - AIC:16.0
# SARIMA(2, 2, 1)x(2, 1, 0, 12) - AIC:12.0
# SARIMA(2, 2, 1)x(2, 1, 1, 12) - AIC:14.0
# SARIMA(2, 2, 1)x(2, 1, 2, 12) - AIC:16.0
# SARIMA(2, 2, 1)x(2, 2, 0, 12) - AIC:12.0
# SARIMA(2, 2, 1)x(2, 2, 1, 12) - AIC:14.0
# SARIMA(2, 2, 1)x(2, 2, 2, 12) - AIC:16.0
# SARIMA(2, 2, 2)x(0, 0, 0, 12) - AIC:448.26734577703536
# SARIMA(2, 2, 2)x(0, 0, 1, 12) - AIC:183.19883728159303
# SARIMA(2, 2, 2)x(0, 0, 2, 12) - AIC:14.0
# SARIMA(2, 2, 2)x(0, 1, 0, 12) - AIC:182.09004093277
# SARIMA(2, 2, 2)x(0, 1, 1, 12) - AIC:12.0
# SARIMA(2, 2, 2)x(0, 1, 2, 12) - AIC:14.0
# SARIMA(2, 2, 2)x(0, 2, 0, 12) - AIC:10.0
# SARIMA(2, 2, 2)x(0, 2, 1, 12) - AIC:12.0
# SARIMA(2, 2, 2)x(0, 2, 2, 12) - AIC:14.0
# SARIMA(2, 2, 2)x(1, 0, 0, 12) - AIC:204.68239244283444
# SARIMA(2, 2, 2)x(1, 0, 1, 12) - AIC:185.13884430682157
# SARIMA(2, 2, 2)x(1, 0, 2, 12) - AIC:16.0
# SARIMA(2, 2, 2)x(1, 1, 0, 12) - AIC:12.0
# SARIMA(2, 2, 2)x(1, 1, 1, 12) - AIC:14.0
# SARIMA(2, 2, 2)x(1, 1, 2, 12) - AIC:16.0
# SARIMA(2, 2, 2)x(1, 2, 0, 12) - AIC:12.0
# SARIMA(2, 2, 2)x(1, 2, 1, 12) - AIC:14.0
# SARIMA(2, 2, 2)x(1, 2, 2, 12) - AIC:16.0
# SARIMA(2, 2, 2)x(2, 0, 0, 12) - AIC:14.0
# SARIMA(2, 2, 2)x(2, 0, 1, 12) - AIC:16.0
# SARIMA(2, 2, 2)x(2, 0, 2, 12) - AIC:18.0
# SARIMA(2, 2, 2)x(2, 1, 0, 12) - AIC:14.0
# SARIMA(2, 2, 2)x(2, 1, 1, 12) - AIC:16.0
# SARIMA(2, 2, 2)x(2, 1, 2, 12) - AIC:18.0
# SARIMA(2, 2, 2)x(2, 2, 0, 12) - AIC:14.0
# SARIMA(2, 2, 2)x(2, 2, 1, 12) - AIC:16.0
# SARIMA(2, 2, 2)x(2, 2, 2, 12) - AIC:18.0
# The set of parameters with the minimum AIC is: SARIMA(0, 0, 0)x(0, 2, 0, 12) - AIC:2.0

# %%
import statsmodels.api as sm
#SARIMA(1, 0, 0)x(0, 1, 1, 12) - AIC:6.0
#SARIMA(1, 0, 0)x(0, 2, 0, 12) - AIC:4.0
#SARIMA(0, 0, 0)x(0, 2, 0, 12) - AIC:2.0
mod = sm.tsa.statespace.SARIMAX(y_train,
                                order=(3,1,0),
                                seasonal_order=(3, 0, 0, 12),
                                #enforce_stationarity=False,
                                #enforce_invertibility=False,
                                freq='M')
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0720      0.262      0.275      0.784      -0.442       0.586
# ar.L2          0.2810      0.233      1.207      0.227      -0.175       0.737
# ar.L3         -0.1346      0.402     -0.335      0.738      -0.923       0.654
# ar.S.L12       0.3945      4.809      0.082      0.935      -9.030       9.819
# ar.S.L24      -0.0092    163.900  -5.59e-05      1.000    -321.247     321.228
# ar.S.L36      -0.0002    411.096  -5.65e-07      1.000    -805.734     805.734
# sigma2       1.78e+08      0.000   3.85e+11      0.000    1.78e+08    1.78e+08
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(16,10))

# %%
pred = results.get_prediction(start=pd.to_datetime('2020-06-01'), end=pd.to_datetime('2022-02-01'),dynamic=False)
pred_ci = pred.conf_int()
ax = y_train.plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(20,7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Demand')
pyplot.legend()
pyplot.show()
pred.predicted_mean
# Out:
# 2020-06     56214.110138
# 2020-07     87044.429000
# 2020-08     86658.302514
# 2020-09    106287.363370
# 2020-10     89738.591770
# 2020-11     65249.607664
# 2020-12     54513.878767
# 2021-01     48827.215085
# 2021-02     62563.303369
# 2021-03     52999.660562
# 2021-04     76616.343928
# 2021-05     95914.850450
# 2021-06    115645.246243
# 2021-07    138099.825422
# 2021-08    139140.351382
# 2021-09    128591.843915
# 2021-10    124787.369086
# 2021-11    116840.897233
# 2021-12    113411.671163
# 2022-01    118248.840924
# 2022-02    114429.572633
# Freq: M, Name: predicted_mean, dtype: float64

# %%
#errors in prediction
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
y_forecasted = pred.predicted_mean.to_frame()
y_truth = y_test['2021-05-01':]
y_forecasted = y_forecasted['2021-05-01':].rename(columns={"predicted_mean": "value"})
y_forecasted=y_forecasted[0:1].round()
y_truth = y_truth.rename(columns={"pageimpression_oop": "value"})
mse=mean_squared_error(y_truth['value'],y_forecasted['value'])
mpe=mean_absolute_percentage_error(y_truth['value'],y_forecasted['value'])
mse2 = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error is {}'.format(round(mse, 2)))
print('The Root Mean Squared Error is {}'.format(round(np.sqrt(mse), 2)))
#print('The Mean Squared Error is {}'.format(round(mpe, 2)))
print('The Root Mean Percentage Squared Error is {}'.format(mpe,2))
# Out:
# The Mean Squared Error is 439153936.0
# The Root Mean Squared Error is 20956.0
# The Root Mean Percentage Squared Error is 0.17930881056891787

# %%
y_forecasted[0:1].round()
# Out:
#             value
# 2021-08  139140.0

# %%
y_truth
# Out:
#             value
# date
# 2021-08  116871.0

# %%
pred_uc = results.get_forecast(steps=12)
pred_ci = pred_uc.conf_int()
ax = y_train.plot(label='observed', figsize=(14, 4))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Page Impressions')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-55b946e83745> in <module>
#       8 ax.set_xlabel('Date')
#       9 ax.set_ylabel('Page Impressions')
# ---> 10 plt.legend()
#      11 plt.show()
#
# NameError: name 'plt' is not defined

# %%
y_forecasted = pred.predicted_mean
y_forecasted.head(12)
# Out:
# 2021-01     48827.215085
# 2021-02     62563.303369
# 2021-03     52999.660562
# 2021-04     76616.343928
# 2021-05     95914.850450
# 2021-06    115645.246243
# 2021-07    138099.825422
# 2021-08    139140.351382
# 2021-09    128591.843915
# 2021-10    124787.369086
# 2021-11    116840.897233
# 2021-12    113411.671163
# Freq: M, Name: predicted_mean, dtype: float64

# %%
y_truth.head(12)
# Out:
#             value
# date
# 2021-08  116871.0

# %%
pred_ci.head(24)
# Out:
#          lower pageimpression_oop  upper pageimpression_oop
# 2021-08             112991.738046             165288.964718
# 2021-09              90257.400442             166926.287388
# 2021-10              72528.901572             177045.836600
# 2021-11              55000.614233             178681.180233
# 2021-12              42482.418354             184340.923971
# 2022-01              39950.185679             196547.496169
# 2022-02              29127.599331             199731.545934
# 2022-03              33533.705781             216625.680232
# 2022-04              28880.267552             223908.545442
# 2022-05              34671.455900             240790.405004
# 2022-06              35399.280284             252145.142281
# 2022-07              31980.795731             258794.946424

# %%
forecast = pred_uc.predicted_mean
forecast.head(12)
forecast.round()
# Out:
# 2021-08    139140.0
# 2021-09    128592.0
# 2021-10    124787.0
# 2021-11    116841.0
# 2021-12    113412.0
# 2022-01    118249.0
# 2022-02    114430.0
# 2022-03    125080.0
# 2022-04    126394.0
# 2022-05    137731.0
# 2022-06    143772.0
# 2022-07    145388.0
# Freq: M, Name: predicted_mean, dtype: float64
